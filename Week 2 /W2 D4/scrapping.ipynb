# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# We found an API option, which would be easier then scraping but did the scraping anyway
#
# https://pypi.org/project/weathercom/

# %%
# (chrome) Webscraper plugin identifies elements to apply to Pandas function, identical to Chrome's Developer Tools

# %% [markdown]
# Here are the result from the Chrome Plugin

# %%
df = pd.read_csv('./result.csv')
df
# Out:
#                                               DayDate  \
# 0   <span class="DailyContent--daypartDate--3MM0J"...
# 1   <span class="DailyContent--daypartDate--3MM0J"...
# 2   <span class="DailyContent--daypartDate--3MM0J"...
# 3   <span class="DailyContent--daypartDate--3MM0J"...
# 4   <span class="DailyContent--daypartDate--3MM0J"...
# 5   <span class="DailyContent--daypartDate--3MM0J"...
# 6   <span class="DailyContent--daypartDate--3MM0J"...
# 7   <span class="DailyContent--daypartDate--3MM0J"...
# 8   <span class="DailyContent--daypartDate--3MM0J"...
# 9   <span class="DailyContent--daypartDate--3MM0J"...
# 10  <span class="DailyContent--daypartDate--3MM0J"...
# 11  <span class="DailyContent--daypartDate--3MM0J"...
# 12  <span class="DailyContent--daypartDate--3MM0J"...
# 13  <span class="DailyContent--daypartDate--3MM0J"...
# 14  <span class="DailyContent--daypartDate--3MM0J"...
# 15  <span class="DailyContent--daypartDate--3MM0J"...
# 16  <span class="DailyContent--daypartDate--3MM0J"...
# 17  <span class="DailyContent--daypartDate--3MM0J"...
# 18  <span class="DailyContent--daypartDate--3MM0J"...
# 19  <span class="DailyContent--daypartDate--3MM0J"...
# 20  <span class="DailyContent--daypartDate--3MM0J"...
# 21  <span class="DailyContent--daypartDate--3MM0J"...
# 22  <span class="DailyContent--daypartDate--3MM0J"...
# 23  <span class="DailyContent--daypartDate--3MM0J"...
# 24  <span class="DailyContent--daypartDate--3MM0J"...
# 25  <span class="DailyContent--daypartDate--3MM0J"...
# 26  <span class="DailyContent--daypartDate--3MM0J"...
# 27  <span class="DailyContent--daypartDate--3MM0J"...
# 28  <span class="DailyContent--daypartDate--3MM0J"...
#
#                                                  Temp  \
# 0   <span data-testid="TemperatureValue" class="Da...
# 1   <span data-testid="TemperatureValue" class="Da...
# 2   <span data-testid="TemperatureValue" class="Da...
# 3   <span data-testid="TemperatureValue" class="Da...
# 4   <span data-testid="TemperatureValue" class="Da...
# 5   <span data-testid="TemperatureValue" class="Da...
# 6   <span data-testid="TemperatureValue" class="Da...
# 7   <span data-testid="TemperatureValue" class="Da...
# 8   <span data-testid="TemperatureValue" class="Da...
# 9   <span data-testid="TemperatureValue" class="Da...
# 10  <span data-testid="TemperatureValue" class="Da...
# 11  <span data-testid="TemperatureValue" class="Da...
# 12  <span data-testid="TemperatureValue" class="Da...
# 13  <span data-testid="TemperatureValue" class="Da...
# 14  <span data-testid="TemperatureValue" class="Da...
# 15  <span data-testid="TemperatureValue" class="Da...
# 16  <span data-testid="TemperatureValue" class="Da...
# 17  <span data-testid="TemperatureValue" class="Da...
# 18  <span data-testid="TemperatureValue" class="Da...
# 19  <span data-testid="TemperatureValue" class="Da...
# 20  <span data-testid="TemperatureValue" class="Da...
# 21  <span data-testid="TemperatureValue" class="Da...
# 22  <span data-testid="TemperatureValue" class="Da...
# 23  <span data-testid="TemperatureValue" class="Da...
# 24  <span data-testid="TemperatureValue" class="Da...
# 25  <span data-testid="TemperatureValue" class="Da...
# 26  <span data-testid="TemperatureValue" class="Da...
# 27  <span data-testid="TemperatureValue" class="Da...
# 28  <span data-testid="TemperatureValue" class="Da...
#
#                                                  Desc
# 0   <p data-testid="wxPhrase" class="DailyContent-...
# 1   <p data-testid="wxPhrase" class="DailyContent-...
# 2   <p data-testid="wxPhrase" class="DailyContent-...
# 3   <p data-testid="wxPhrase" class="DailyContent-...
# 4   <p data-testid="wxPhrase" class="DailyContent-...
# 5   <p data-testid="wxPhrase" class="DailyContent-...
# 6   <p data-testid="wxPhrase" class="DailyContent-...
# 7   <p data-testid="wxPhrase" class="DailyContent-...
# 8   <p data-testid="wxPhrase" class="DailyContent-...
# 9   <p data-testid="wxPhrase" class="DailyContent-...
# 10  <p data-testid="wxPhrase" class="DailyContent-...
# 11  <p data-testid="wxPhrase" class="DailyContent-...
# 12  <p data-testid="wxPhrase" class="DailyContent-...
# 13  <p data-testid="wxPhrase" class="DailyContent-...
# 14  <p data-testid="wxPhrase" class="DailyContent-...
# 15  <p data-testid="wxPhrase" class="DailyContent-...
# 16  <p data-testid="wxPhrase" class="DailyContent-...
# 17  <p data-testid="wxPhrase" class="DailyContent-...
# 18  <p data-testid="wxPhrase" class="DailyContent-...
# 19  <p data-testid="wxPhrase" class="DailyContent-...
# 20  <p data-testid="wxPhrase" class="DailyContent-...
# 21  <p data-testid="wxPhrase" class="DailyContent-...
# 22  <p data-testid="wxPhrase" class="DailyContent-...
# 23  <p data-testid="wxPhrase" class="DailyContent-...
# 24  <p data-testid="wxPhrase" class="DailyContent-...
# 25  <p data-testid="wxPhrase" class="DailyContent-...
# 26  <p data-testid="wxPhrase" class="DailyContent-...
# 27  <p data-testid="wxPhrase" class="DailyContent-...
# 28  <p data-testid="wxPhrase" class="DailyContent-...

# %%
# get the web page
page = requests.get("https://weather.com/weather/tenday/l/69bedc6a5b6e977993fb3e5344e3c06d8bc36a1fb6754c3ddfb5310a3c6d6c87")
#parse html
soup = BeautifulSoup(page.content, 'html.parser')
#Grab the varibales we need 
dailysummary = soup.find_all(class_="DailyContent--narrative--3AcXd")
temp = soup.find_all(class_="DailyContent--temp--_8DL5")
date = soup.find_all(class_="DailyContent--daypartDate--3MM0J")

print(date)
print(dailysummary)
print(temp)
# Out:
# [<span class="DailyContent--daypartDate--3MM0J">Wed 09</span>, <span class="DailyContent--daypartDate--3MM0J">Wed 09</span>, <span class="DailyContent--daypartDate--3MM0J">Thu 10</span>, <span class="DailyContent--daypartDate--3MM0J">Thu 10</span>, <span class="DailyContent--daypartDate--3MM0J">Fri 11</span>, <span class="DailyContent--daypartDate--3MM0J">Fri 11</span>, <span class="DailyContent--daypartDate--3MM0J">Sat 12</span>, <span class="DailyContent--daypartDate--3MM0J">Sat 12</span>, <span class="DailyContent--daypartDate--3MM0J">Sun 13</span>, <span class="DailyContent--daypartDate--3MM0J">Sun 13</span>, <span class="DailyContent--daypartDate--3MM0J">Mon 14</span>, <span class="DailyContent--daypartDate--3MM0J">Mon 14</span>, <span class="DailyContent--daypartDate--3MM0J">Tue 15</span>, <span class="DailyContent--daypartDate--3MM0J">Tue 15</span>, <span class="DailyContent--daypartDate--3MM0J">Wed 16</span>, <span class="DailyContent--daypartDate--3MM0J">Wed 16</span>, <span class="DailyContent--daypartDate--3MM0J">Thu 17</span>, <span class="DailyContent--daypartDate--3MM0J">Thu 17</span>, <span class="DailyContent--daypartDate--3MM0J">Fri 18</span>, <span class="DailyContent--daypartDate--3MM0J">Fri 18</span>, <span class="DailyContent--daypartDate--3MM0J">Sat 19</span>, <span class="DailyContent--daypartDate--3MM0J">Sat 19</span>, <span class="DailyContent--daypartDate--3MM0J">Sun 20</span>, <span class="DailyContent--daypartDate--3MM0J">Sun 20</span>, <span class="DailyContent--daypartDate--3MM0J">Mon 21</span>, <span class="DailyContent--daypartDate--3MM0J">Mon 21</span>, <span class="DailyContent--daypartDate--3MM0J">Tue 22</span>, <span class="DailyContent--daypartDate--3MM0J">Tue 22</span>, <span class="DailyContent--daypartDate--3MM0J">Wed 23</span>, <span class="DailyContent--daypartDate--3MM0J">Wed 23</span>]
# [<p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">A mix of clouds and sun. High 63F. Winds N at 5 to 10 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Partly cloudy this evening with more clouds for overnight. Low 44F. Winds light and variable.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Some clouds in the morning will give way to mainly sunny skies for the afternoon. High 57F. Winds W at 15 to 25 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Mostly clear evening skies will give way to mostly cloudy skies overnight. Low 44F. Winds NW at 15 to 25 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Partly cloudy. High 56F. Winds NW at 5 to 10 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Mostly cloudy in the evening then periods of showers after midnight. Low near 45F. Winds SW at 5 to 10 mph. Chance of rain 60%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Cloudy with occasional rain showers. High 56F. Winds SSE at 5 to 10 mph. Chance of rain 60%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Cloudy with occasional showers late at night. Low 47F. Winds ESE at 5 to 10 mph. Chance of rain 60%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">A steady rain in the morning. Showers continuing in the afternoon. High 58F. Winds SSW at 10 to 20 mph. Chance of rain 70%. Rainfall around a quarter of an inch.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Overcast with rain showers at times. Low 47F. Winds W at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Partly cloudy skies. High 58F. Winds WNW at 10 to 15 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Mostly clear during the evening followed by mostly cloudy skies overnight. Low 44F. Winds WNW at 5 to 10 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Sunshine and clouds mixed. High 57F. Winds W at 5 to 10 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Partly cloudy skies early followed by increasing clouds with showers developing later at night. Low 44F. Winds W at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Considerable cloudiness with occasional rain showers. High 58F. Winds W at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Cloudy with occasional rain showers. Low near 45F. Winds WSW at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Rain showers in the morning becoming more intermittent in the afternoon. High 58F. Winds W at 10 to 15 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Considerable cloudiness. Low around 45F. Winds WNW at 5 to 10 mph.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">A few showers early with mostly cloudy conditions later in the day. High 58F. Winds NW at 5 to 10 mph. Chance of rain 30%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Overcast with rain showers at times. Low 44F. Winds light and variable. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Rain showers early with mostly cloudy conditions later in the day. High 59F. Winds WNW at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Cloudy with a few showers. Low 44F. Winds light and variable. Chance of rain 30%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Rain showers early with some sunshine later in the day. High around 60F. Winds NW at 5 to 10 mph. Chance of rain 40%.</p>, <p class="DailyContent--narrative--3AcXd" data-testid="wxPhrase">Part ...
# [<span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">63°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">57°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">56°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">45°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">56°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">47°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">58°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">47°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">58°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">57°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">58°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">45°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">58°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">45°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">58°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">59°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">44°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">60°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">43°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">60°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">42°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">60°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">42°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">60°</span>, <span class="DailyContent--temp--_8DL5" data-testid="TemperatureValue">42°</span>]

# %%
# -*- coding: utf-8 -*-
# Tidy up data
dateClean = []
dayClean = []
tempClean = []
sumClean = []
dn = []

for d in date:
    dd = d.get_text()
    ddd = dd.split(" ")
    dateClean.append(ddd[1])
    dayClean.append(ddd[0])

for t in temp:
    tst = t.get_text()
    tt = re.sub('[^0-9]', '', tst)
    # T(°C) = (T(°F) - 32) × 5/9
    tc = (int(tt)-32) * 5/9
    tempClean.append(tc)

for s in dailysummary:
    ss = s.get_text()
    sumClean.append(ss)

for i in range(0,30):
    if i % 2 !=0:
        dn.append("d")
    else:
        dn.append("n")  

  
data_dict = {"day": dayClean, "date": dateClean, "temp": tempClean, 'Summary': sumClean, "day/night":dn}
#print(dateClean)
#print(dayClean)
#print(tempClean)
print(len(sumClean))
print(data_dict)
# Out:
# 30
# {'day': ['Wed', 'Wed', 'Thu', 'Thu', 'Fri', 'Fri', 'Sat', 'Sat', 'Sun', 'Sun', 'Mon', 'Mon', 'Tue', 'Tue', 'Wed', 'Wed', 'Thu', 'Thu', 'Fri', 'Fri', 'Sat', 'Sat', 'Sun', 'Sun', 'Mon', 'Mon', 'Tue', 'Tue', 'Wed', 'Wed'], 'date': ['09', '09', '10', '10', '11', '11', '12', '12', '13', '13', '14', '14', '15', '15', '16', '16', '17', '17', '18', '18', '19', '19', '20', '20', '21', '21', '22', '22', '23', '23'], 'temp': [17.22222222222222, 6.666666666666667, 13.88888888888889, 6.666666666666667, 13.333333333333334, 7.222222222222222, 13.333333333333334, 8.333333333333334, 14.444444444444445, 8.333333333333334, 14.444444444444445, 6.666666666666667, 13.88888888888889, 6.666666666666667, 14.444444444444445, 7.222222222222222, 14.444444444444445, 7.222222222222222, 14.444444444444445, 6.666666666666667, 15.0, 6.666666666666667, 15.555555555555555, 6.111111111111111, 15.555555555555555, 5.555555555555555, 15.555555555555555, 5.555555555555555, 15.555555555555555, 5.555555555555555], 'Summary': ['A mix of clouds and sun. High 63F. Winds N at 5 to 10 mph.', 'Partly cloudy this evening with more clouds for overnight. Low 44F. Winds light and variable.', 'Some clouds in the morning will give way to mainly sunny skies for the afternoon. High 57F. Winds W at 15 to 25 mph.', 'Mostly clear evening skies will give way to mostly cloudy skies overnight. Low 44F. Winds NW at 15 to 25 mph.', 'Partly cloudy. High 56F. Winds NW at 5 to 10 mph.', 'Mostly cloudy in the evening then periods of showers after midnight. Low near 45F. Winds SW at 5 to 10 mph. Chance of rain 60%.', 'Cloudy with occasional rain showers. High 56F. Winds SSE at 5 to 10 mph. Chance of rain 60%.', 'Cloudy with occasional showers late at night. Low 47F. Winds ESE at 5 to 10 mph. Chance of rain 60%.', 'A steady rain in the morning. Showers continuing in the afternoon. High 58F. Winds SSW at 10 to 20 mph. Chance of rain 70%. Rainfall around a quarter of an inch.', 'Overcast with rain showers at times. Low 47F. Winds W at 5 to 10 mph. Chance of rain 40%.', 'Partly cloudy skies. High 58F. Winds WNW at 10 to 15 mph.', 'Mostly clear during the evening followed by mostly cloudy skies overnight. Low 44F. Winds WNW at 5 to 10 mph.', 'Sunshine and clouds mixed. High 57F. Winds W at 5 to 10 mph.', 'Partly cloudy skies early followed by increasing clouds with showers developing later at night. Low 44F. Winds W at 5 to 10 mph. Chance of rain 40%.', 'Considerable cloudiness with occasional rain showers. High 58F. Winds W at 5 to 10 mph. Chance of rain 40%.', 'Cloudy with occasional rain showers. Low near 45F. Winds WSW at 5 to 10 mph. Chance of rain 40%.', 'Rain showers in the morning becoming more intermittent in the afternoon. High 58F. Winds W at 10 to 15 mph. Chance of rain 40%.', 'Considerable cloudiness. Low around 45F. Winds WNW at 5 to 10 mph.', 'A few showers early with mostly cloudy conditions later in the day. High 58F. Winds NW at 5 to 10 mph. Chance of rain 30%.', 'Overcast with rain showers at times. Low 44F. Winds light and variable. Chance of rain 40%.', 'Rain showers early with mostly cloudy conditions later in the day. High 59F. Winds WNW at 5 to 10 mph. Chance of rain 40%.', 'Cloudy with a few showers. Low 44F. Winds light and variable. Chance of rain 30%.', 'Rain showers early with some sunshine later in the day. High around 60F. Winds NW at 5 to 10 mph. Chance of rain 40%.', 'Partly cloudy during the evening. A few showers developing later during the night. Low 43F. Winds NW at 5 to 10 mph. Chance of rain 30%.', 'A shower or two possible early with partly cloudy skies in the afternoon. High around 60F. Winds NW at 5 to 10 mph. Chance of rain 30%.', 'A few showers in the evening, then clouds lingering overnight. Low 42F. Winds NW at 5 to 10 mph. Chance of rain 30%.', 'Sunshine along with some cloudy intervals. High around 60F. Winds NNW at 5 to 10 mph.', 'Mostly clear skies early then becoming mostly cloudy later at night. Low 42F. Winds N at 5 to 10 mph.', 'Partly cloudy. Hi ...

# %% [markdown]
# Here we decided to try 2 fdifferent approachs, the first uses pyhton to manipulate the data, the second uses pandas to manipulate the data.

# %%
#Make changes to data before pandas 
nDay = dayClean[::2]
nDate = dateClean[::2]
high = []
low = []
new_sum = []

for te in tempClean:
    ind = tempClean.index(te)
    if ind % 2 != 0:
        ns = "Day: " + sumClean[ind] + "Night: " + sumClean[ind+1]
        high.append(te)
        new_sum.append(ns)
    else: 
        low.append(te)

new_data_dict = {"date":nDate, "day":nDay, "summary":new_sum, "highTemp":high, "lowTemp": low}
w_dn = pd.DataFrame(new_data_dict)
w_dn
# Out:
#    date  day                                            summary  highTemp  \
# 0    09  Wed  Day: Partly cloudy this evening with more clou...  6.666667
# 1    10  Thu  Day: Partly cloudy this evening with more clou...  6.666667
# 2    11  Fri  Day: Mostly cloudy in the evening then periods...  7.222222
# 3    12  Sat  Day: Cloudy with occasional showers late at ni...  8.333333
# 4    13  Sun  Day: Cloudy with occasional showers late at ni...  8.333333
# 5    14  Mon  Day: Partly cloudy this evening with more clou...  6.666667
# 6    15  Tue  Day: Partly cloudy this evening with more clou...  6.666667
# 7    16  Wed  Day: Mostly cloudy in the evening then periods...  7.222222
# 8    17  Thu  Day: Mostly cloudy in the evening then periods...  7.222222
# 9    18  Fri  Day: Partly cloudy this evening with more clou...  6.666667
# 10   19  Sat  Day: Partly cloudy this evening with more clou...  6.666667
# 11   20  Sun  Day: Partly cloudy during the evening. A few s...  6.111111
# 12   21  Mon  Day: A few showers in the evening, then clouds...  5.555556
# 13   22  Tue  Day: A few showers in the evening, then clouds...  5.555556
# 14   23  Wed  Day: A few showers in the evening, then clouds...  5.555556
#
#       lowTemp
# 0   17.222222
# 1   13.888889
# 2   13.333333
# 3   13.333333
# 4   14.444444
# 5   14.444444
# 6   13.888889
# 7   14.444444
# 8   14.444444
# 9   14.444444
# 10  15.000000
# 11  15.555556
# 12  15.555556
# 13  15.555556
# 14  15.555556

# %%
#Making the mat plot lib 
# this only works in Juypter note book not deepnote 
w_dn['date'] = w_dn['date'].astype(float)
w_dn.plot()
plt.show()

# %% [markdown]
# ## Second approach

# %%
weather1  = pd.DataFrame(data_dict)
weather2 = weather1
weather3 = weather1
#print(weather2.drop_duplicates('date'))
#print(weather3.drop_duplicates('date',keep='last'))
weather2 = weather2.drop_duplicates('date')
weather3 = weather3.drop_duplicates('date',keep='last')

weather2 = weather2.reset_index()
weather3 = weather3.reset_index()
weather2 = weather2.rename(columns={'temp':'highTemp', 'Summary':'Day_Summary'})
weather3 = weather3.rename(columns={'temp':"lowTemp", 'Summary' : 'Night_Summary'})


Comdf = weather2.merge(weather3,how='inner', on=['day','date'])

finalframe = Comdf[["day","date","highTemp","lowTemp","Day_Summary","Night_Summary"]]
finalframe


#thanks

#weather2.
# Out:
#     day date   highTemp   lowTemp  \
# 0   Wed   09  17.222222  6.666667
# 1   Thu   10  13.888889  6.666667
# 2   Fri   11  13.333333  7.222222
# 3   Sat   12  13.333333  8.333333
# 4   Sun   13  14.444444  8.333333
# 5   Mon   14  14.444444  6.666667
# 6   Tue   15  13.888889  6.666667
# 7   Wed   16  14.444444  7.222222
# 8   Thu   17  14.444444  7.222222
# 9   Fri   18  14.444444  6.666667
# 10  Sat   19  15.000000  6.666667
# 11  Sun   20  15.555556  6.111111
# 12  Mon   21  15.555556  5.555556
# 13  Tue   22  15.555556  5.555556
# 14  Wed   23  15.555556  5.555556
#
#                                           Day_Summary  \
# 0   A mix of clouds and sun. High 63F. Winds N at ...
# 1   Some clouds in the morning will give way to ma...
# 2   Partly cloudy. High 56F. Winds NW at 5 to 10 mph.
# 3   Cloudy with occasional rain showers. High 56F....
# 4   A steady rain in the morning. Showers continui...
# 5   Partly cloudy skies. High 58F. Winds WNW at 10...
# 6   Sunshine and clouds mixed. High 57F. Winds W a...
# 7   Considerable cloudiness with occasional rain s...
# 8   Rain showers in the morning becoming more inte...
# 9   A few showers early with mostly cloudy conditi...
# 10  Rain showers early with mostly cloudy conditio...
# 11  Rain showers early with some sunshine later in...
# 12  A shower or two possible early with partly clo...
# 13  Sunshine along with some cloudy intervals. Hig...
# 14  Partly cloudy. High near 60F. Winds N at 5 to ...
#
#                                         Night_Summary
# 0   Partly cloudy this evening with more clouds fo...
# 1   Mostly clear evening skies will give way to mo...
# 2   Mostly cloudy in the evening then periods of s...
# 3   Cloudy with occasional showers late at night. ...
# 4   Overcast with rain showers at times. Low 47F. ...
# 5   Mostly clear during the evening followed by mo...
# 6   Partly cloudy skies early followed by increasi...
# 7   Cloudy with occasional rain showers. Low near ...
# 8   Considerable cloudiness. Low around 45F. Winds...
# 9   Overcast with rain showers at times. Low 44F. ...
# 10  Cloudy with a few showers. Low 44F. Winds ligh...
# 11  Partly cloudy during the evening. A few shower...
# 12  A few showers in the evening, then clouds ling...
# 13  Mostly clear skies early then becoming mostly ...
# 14  Mostly clear evening skies will give way to mo...

# %% [markdown]
# ##Sergey Brin
#
# Each "h2" element as a column of you final pandas dataframe
#
# What can you scrape that makes sense? Think about creating a dataset.
# Places, dates, content. Some values will be NaN.

# %%
sg_site = requests.get('http://infolab.stanford.edu/~sergey/resume.html')
sg_soup = BeautifulSoup(sg_site.content, 'html.parser')

h_2_tags = sg_soup.find_all('h2')
cols = []
for h in h_2_tags:
    cols.append(h.get_text())

#print(sg_soup.prettify())

# %% [markdown]
# ##Some Other Websites - Football transfers
#
# Scraping bonus task

# %%
f_pages = requests.get ('https://www.ox.ac.uk/admissions/undergraduate/courses/course-listing')
f_soup = BeautifulSoup(f_pages.content, 'html.parser')
f_body = f_soup.find("body")
#tbc

# %% [markdown]
# This is the 2 line version of the approach above

# %%
# the one line version 
weather1  = pd.DataFrame(data_dict)
weather2 = weather1
weather3 = weather1

weather2 = weather2.drop_duplicates('date').reset_index().rename(columns={'temp':'highTemp', 'Summary':'Day_Summary'})
weather3 = weather3.drop_duplicates('date',keep='last').reset_index().rename(columns={'temp':"lowTemp", 'Summary' : 'Night_Summary'})

Comdf = weather2.merge(weather3,how='inner', on=['day','date'])

finalframe = Comdf[["day","date","highTemp","lowTemp","Day_Summary","Night_Summary"]]
finalframe['highTemp'] = finalframe['highTemp'].round(decimals=2)
finalframe
#thanks

#weather2
# Out:
# /opt/venv/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#     day date  highTemp   lowTemp  \
# 0   Wed   09     17.22  6.666667
# 1   Thu   10     13.89  6.666667
# 2   Fri   11     13.33  7.222222
# 3   Sat   12     13.33  8.333333
# 4   Sun   13     14.44  8.333333
# 5   Mon   14     14.44  6.666667
# 6   Tue   15     13.89  6.666667
# 7   Wed   16     14.44  7.222222
# 8   Thu   17     14.44  7.222222
# 9   Fri   18     14.44  6.666667
# 10  Sat   19     15.00  6.666667
# 11  Sun   20     15.56  6.111111
# 12  Mon   21     15.56  5.555556
# 13  Tue   22     15.56  5.555556
# 14  Wed   23     15.56  5.555556
#
#                                           Day_Summary  \
# 0   A mix of clouds and sun. High 63F. Winds N at ...
# 1   Some clouds in the morning will give way to ma...
# 2   Partly cloudy. High 56F. Winds NW at 5 to 10 mph.
# 3   Cloudy with occasional rain showers. High 56F....
# 4   A steady rain in the morning. Showers continui...
# 5   Partly cloudy skies. High 58F. Winds WNW at 10...
# 6   Sunshine and clouds mixed. High 57F. Winds W a...
# 7   Considerable cloudiness with occasional rain s...
# 8   Rain showers in the morning becoming more inte...
# 9   A few showers early with mostly cloudy conditi...
# 10  Rain showers early with mostly cloudy conditio...
# 11  Rain showers early with some sunshine later in...
# 12  A shower or two possible early with partly clo...
# 13  Sunshine along with some cloudy intervals. Hig...
# 14  Partly cloudy. High near 60F. Winds N at 5 to ...
#
#                                         Night_Summary
# 0   Partly cloudy this evening with more clouds fo...
# 1   Mostly clear evening skies will give way to mo...
# 2   Mostly cloudy in the evening then periods of s...
# 3   Cloudy with occasional showers late at night. ...
# 4   Overcast with rain showers at times. Low 47F. ...
# 5   Mostly clear during the evening followed by mo...
# 6   Partly cloudy skies early followed by increasi...
# 7   Cloudy with occasional rain showers. Low near ...
# 8   Considerable cloudiness. Low around 45F. Winds...
# 9   Overcast with rain showers at times. Low 44F. ...
# 10  Cloudy with a few showers. Low 44F. Winds ligh...
# 11  Partly cloudy during the evening. A few shower...
# 12  A few showers in the evening, then clouds ling...
# 13  Mostly clear skies early then becoming mostly ...
# 14  Mostly clear evening skies will give way to mo...
